# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager

# 1. Configurar opciones para WSL (Headless)
chrome_options = Options()
chrome_options.add_argument("--headless")  # Ejecuta sin interfaz gráfica
chrome_options.add_argument("--no-sandbox") # Necesario para entornos Linux/Docker
chrome_options.add_argument("--disable-dev-shm-usage") # Evita errores de memoria compartida

# 2. Setup automático del driver
# Esto busca tu versión de Chrome, descarga el driver compatible y lo arranca.
service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=chrome_options)

# 3. Prueba de fuego
try:
    driver.get("https://www.google.com")
    print("¡Éxito! El título de la página es:", driver.title)
finally:
    driver.quit()
# Out:
# ¡Éxito! El título de la página es: Google
